# %% [markdown]
# # Desenvolvimento Colaborativo 🤝

# %% [markdown]
# ## Sumário da Aula

# %% [markdown]
# <ul>
#     <li>Configuração ⚙️</li>
#     <ul>
#         <li>Git 📸</li>
#         <li>GitHub 🔧</li>
#     </ul>
#     <li>Aspectos de Desenvolvimento Colaborativo 🤝</li>
#     <ul>
#         <li>Versionamento de Projeto pelo Líder 👨🏻‍🍳</li>
#         <li>Versionamento de Projeto pelo Parceiro 🧑🏽‍💻</li>
#     </ul>
#     <li>Saiba Mais 👩‍🏫</li>
# </ul>

# %% [markdown]
# ### Biblioteca Principal 📚: Não se aplica

# %% [markdown]
# ## Configuração ⚙️

# %% [markdown]
# ### Git 📸

# %% [markdown]
# "Git is a free and open source distributed version control system designed to handle everything from small to very large projects with speed and efficiency."

# %% [markdown]
# <img src="https://git-scm.com/images/logo@2x.png" width="100" style="float: right;">

# %% [markdown]
# 👉 Faça a Instalação: <a href='https://git-scm.com/downloads'>git-scm.com</a>

# %% [markdown]
# 👉 Git <a href='https://education.github.com/git-cheat-sheet-education.pdf'>cheat sheet</a>

# %% [markdown]
# ### GitHub 🔧

# %% [markdown]
# "GitHub is where over 100 million developers shape the future of software, together. Contribute to the open source community, manage your Git repositories, review code like a pro, track bugs and features, power your CI/CD and DevOps workflows, and secure code before you commit it."

# %% [markdown]
# <img src="https://github.githubassets.com/images/modules/logos_page/GitHub-Mark.png" width="100" style="float: right;">

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/6351798/48032310-63842400-e114-11e8-8db0-06dc0504dcb5.png" width='500' style="margin-left: auto; margin-right: auto;">

# %% [markdown]
# 👉 Caso não tenha uma conta no GitHub, <a href='https://github.com/join'>crie uma</a>.

# %% [markdown]
# #### Linha de comando

# %% [markdown]
# 👉 Faça a Instalação: <a href='https://cli.github.com/'>cli.github.com</a>

# %% [markdown]
# 👉 Referência: <a href='https://cli.github.com/manual/'>cli.github.com</a>

# %% [markdown]
# <pre>Após a instalação, para fazer o login no GitHub, copie e cole o seguinte comando no seu terminal:</pre>

# %% [markdown]
# <code>gh auth login -w</code>

# %% [markdown]
# <pre>O gh fará algumas perguntas:</pre>

# %% [markdown]
# <code>What is your preferred protocol for Git operations?</code>

# %% [markdown]
# <pre>Com as setas, escolha <b>SSH</b> e pressione <b>Enter</b>. SSH é um protocolo seguro para fazer login usando chaves SSH.</pre>

# %% [markdown]
# <code>Generate a new SSH key to add to your GitHub account?</code>

# %% [markdown]
# <pre>Pressione <b>Enter</b> para pedir ao gh para gerar as chaves SSH para você. Caso tenha chaves SSH previamente configuradas, em vez da frase acima, verá <b>Upload your SSH public key to your GitHub account?</b>. Com as setas, selecione o caminho do arquivo de chave pública e pressione <b>Enter</b>.</pre>

# %% [markdown]
# <code>Enter a passphrase for your new SSH key (Optional)</code>

# %% [markdown]
# <pre>Frase secreta é uma senha para proteger sua chave privada armazenada em seu disco rígido. Enquando você digita sua senha, nada aparece na tela, isso é normal. Basta digitar sua senha e, quando terminar, pressione <b>Enter</b>. Você então obterá a seguinte saída:</pre>

# %% [markdown]
# <code>! First copy your one-time code: 08F4-2DC3</code>

# %% [markdown]
# <code>Press Enter to open github.com in your browser...</code>

# %% [markdown]
# <pre>Selecione e copie o código (08F4-2DC3 no exemplo) e pressione <b>Enter</b>. Seu navegador será aberto e solicitará que você autorize o GitHub CLI a usar sua conta do GitHub. Proceda conforme as próximas telas.</pre>

# %% [markdown]
# <img src="figs/terminal.png" width="100%">

# %% [markdown]
# <img src="figs/gh auth login 01.png" width="100%">

# %% [markdown]
# <img src="figs/gh auth login 02.png" width="100%">

# %% [markdown]
# <img src="figs/gh auth login 03.png" width="100%">

# %% [markdown]
# <img src="figs/gh auth login 04.png" width="100%">

# %% [markdown]
# <img src="figs/gh auth login 05.png" width="100%">

# %% [markdown]
# <img src="figs/gh auth login 06.png" width="100%">

# %% [markdown]
# ## Aspectos de Desenvolvimento Colaborativo 🤝

# %% [markdown]
# ### Versionamento de Projeto pelo Líder 👨🏻‍🍳

# %% [markdown]
# <pre>Entre na pasta em que deseja criar o projeto (o projeto ficará armazenado em uma subpasta!) e crie um versionamento para o projeto com o comando a seguir.</pre>

# %% [markdown]
# <code>gh repo create</code>

# %% [markdown]
# <pre>O gh fará algumas perguntas:</pre>

# %% [markdown]
# <code>What would you like to do?</code>

# %% [markdown]
# <pre>Com as setas, escolha <b>Create a new repository on GitHub from scratch</b> e pressione <b>Enter</b>. É a opção que permite criar um repositório totalmente novo.</pre>

# %% [markdown]
# <code>Repository name</code>

# %% [markdown]
# <pre>Forneça um nome para o repositório que você está criando e pressione <b>Enter</b>.</pre>

# %% [markdown]
# <code>Repository owner</code>

# %% [markdown]
# <pre>Com as setas, escolha seu usuário e pressione <b>Enter</b>. É possível que outras opções apareçam, por exemplo, caso você tenha sua conta associada a uma instituição.</pre>

# %% [markdown]
# <code>Description</code>

# %% [markdown]
# <pre>Forneça uma descrição do repositório e pressione <b>Enter</b>.</pre>

# %% [markdown]
# <code>Visibility</code>

# %% [markdown]
# <pre>Com as setas, escolha <b>public</b> e pressione <b>Enter</b>. Precisamos do repositório público para rodarmos nosso Aplicativo web 🕸️ 💻 para Ciência de Dados 👨🏽‍🔬. A opção <b>public</b> permite que qualquer pessoa na Internet possa ver o repositório e, posteriormente, você poderá escolher quem pode submeter alterações ao projeto. A opção <b>private</b> permite você escolher quem pode ver e submeter alterações ao repositório.</pre>

# %% [markdown]
# <code>Would you like to add a README file?</code>

# %% [markdown]
# <pre>Digite <b>Y</b> e pressione <b>Enter</b>. É no arquivo README.md que você pode escrever uma descrição longa para o seu projeto.
#
# 👉 <a href='https://docs.github.com/github/creating-cloning-and-archiving-repositories/about-readmes'>Saiba mais</a>.</pre>

# %% [markdown]
# <code>Would you like to add a .gitignore?</code>

# %% [markdown]
# <pre>Digite <b>Y</b> e pressione <b>Enter</b>. É no arquivo .gitignore que você vai listar quais arquivos (pastas inclusas) não devem ser rastreadas pelo git.
#
# 👉 <a href='https://docs.github.com/github/using-git/ignoring-files'>Saiba mais</a>.</pre>

# %% [markdown]
# <code>Choose a .gitignore template</code>

# %% [markdown]
# <pre>Digite <b>Python</b> e pressione <b>Enter</b>.</pre>

# %% [markdown]
# <code>Would you like to add a license?</code>

# %% [markdown]
# <pre>Faça uma escolha consciente sobre a licença desejada e pressione <b>Enter</b>. Uma licença informa aos outros o que eles podem ou não fazer com seu código.
#
# 👉 <a href='https://docs.github.com/github/creating-cloning-and-archiving-repositories/licensing-a-repository'>Saiba mais</a>.</pre>

# %% [markdown]
# <code>Continue?</code>

# %% [markdown]
# <pre>Pressione <b>Enter</b> para criar um repositório totalmente novo no GitHub com as informações fornecidas por você. Após a criação do repositório, entre na pasta criada e crie uma subpasta para grandes arquivos que será ignorado pelo git.</pre>

# %% [markdown]
# <code>mkdir data</code>

# %% [markdown]
# <code>echo 'data/' > .gitignore</code>

# %% [markdown]
# <code>git add .gitignore</code>

# %% [markdown]
# <code>git commit -m 'pasta data/ criada para armazenar arquivos grandes que não serão carregados no GitHub'</code>

# %% [markdown]
# <pre>Submeta suas modificações para o GitHub. Proceda conforme as próximas telas.</pre>

# %% [markdown]
# <code>git push</code>

# %% [markdown]
# <img src="figs/terminal.png" width="100%">

# %% [markdown]
# <img src="figs/git 01.png" width="100%">

# %% [markdown]
# <img src="figs/git 02.png" width="100%">

# %% [markdown]
# <img src="figs/git 03.png" width="100%">

# %% [markdown]
# <img src="figs/git 04.png" width="100%">

# %% [markdown]
# <pre>Você pode, alternativamente, criar repositório pela <a href='https://github.com/new'>plataforma do GitHub</a> e seguir os passos recomendados.</pre>

# %% [markdown]
# <img src="figs/git v2.png" width="100%">

# %% [markdown]
# <pre>No GitHub, adicione os colaboradores do seu projeto em <b>Settings</b> > <b>Collaborators</b>.</pre>

# %% [markdown]
# ### Versionamento de Projeto pelo Parceiro 🧑🏽‍💻

# %% [markdown]
# <pre>Entre na pasta em que deseja <b>clonar</b> o projeto (o projeto ficará armazenado em uma subpasta!) e crie um versionamento para o projeto com o comando a seguir.</pre>

# %% [markdown]
# <code>gh repo clone \<conta-do-lider-do-projeto\>/\<nome-do-projeto\></code>

# %% [markdown]
# <img src="figs/git partner.png" width="100%">

# %% [markdown]
# ## Saiba Mais 👩‍🏫

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(id='KMOmw19ZCGs', width='100%')
